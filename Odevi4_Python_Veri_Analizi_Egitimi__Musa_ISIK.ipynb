# %% [markdown]
# <a href="https://colab.research.google.com/github/musa-isik/GMKA_Musa_ISIK/blob/main/Odevi4_Python_Veri_Analizi_Egitimi__Musa_ISIK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Güney Marmara ve TRAI
# # <center> Python Veri Analizi Eğitimi
# # <center> Ödev 4

# %% [markdown]
# ### Veriyi özetleme

# %% [markdown]
# 1.  3. Ders sonunda hazırladığınız 2021 ve 2022 yıllarına ait BIST30 ve EUR/TRY kur değerlerini içeren bileşke tablodan sadece ayın son işgününe ait değerleri içeren bir pivot tablo üretiniz.

# %%
import yfinance as yf
import pandas as pd
import plotly.express as px

# %%
indirme_listesi=['XU030.IS','EURTRY=X']
Veri=pd.DataFrame()

for i in indirme_listesi:
  data = yf.download(i,start='2021-01-01',end='2022-12-31')
  data=data['Adj Close'].rename(i) 
  Veri=pd.concat([Veri,data],axis=1) 

Veri.index = pd.to_datetime(Veri.index)# İndirdiğim verinin tarih sütunu datetimeindex olmadığı için strftime kodu çalışmadı. Bu yüzden tip dönüşümü yaptım
Veri.index

Veri.columns=['Kapanış (TRY)','EUR/TRY']
Veri['ay_yıl']=Veri.index.strftime('%Y-%m')

Veri=Veri[Veri['Kapanış (TRY)']>0]
Veri
Veri_as=Veri.pivot_table(values=['Kapanış (TRY)','EUR/TRY'],index='ay_yıl',aggfunc='last')
Veri_as
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            EUR/TRY  Kapanış (TRY)
# ay_yıl
# 2021-01   8.902570    1572.400024
# 2021-02   8.904670    1556.000000
# 2021-03   9.748300    1430.699951
# 2021-04   9.923590    1456.900024
# 2021-05  10.347560    1506.900024
# 2021-06  10.384030    1462.900024
# 2021-07  10.050560    1500.800049
# 2021-08   9.869130    1588.300049
# 2021-09  10.343790    1505.199951
# 2021-10  11.003230    1635.699951
# 2021-11  14.347000    1942.800049
# 2021-12  14.993060    2025.000000
# 2022-01  15.034780    2202.600098
# 2022-02  15.688630    2186.300049
# 2022-03  16.353970    2477.199951
# 2022-04  15.531140    2704.399902
# 2022-05  17.646820    2837.600098
# 2022-06  17.240959    2609.199951
# 2022-07  18.285971    2760.500000
# 2022-08  18.194550    3454.399902
# 2022-09  18.145809    3457.600098
# 2022-10  18.480520    4330.500000
# 2022-11  19.230379    5364.399902
# 2022-12  19.937571    5944.799805

# %% [markdown]
# 2. Ay kırılımlı olarak ürettiğiniz tabloyu grafik olarak inceleyiniz.

# %%
Veri_as['Degisim'] = Veri_as['Kapanış (TRY)'].diff(1)
Veri_as['d_yon']=Veri_as['Degisim'].map(lambda x:'dusen gun' if x<0 else 'yukselen gun')
Veri_as['Degisim%']=(Veri_as['Degisim']/Veri_as['Kapanış (TRY)'].shift(1))

px.bar(Veri_as,y='Degisim%',
       color='d_yon',
       color_discrete_map={'dusen gun' : 'red','yukselen gun' : 'green'},
       text_auto='.0%'
       )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3c4362c6-0515-46fc-95a1-6e81a1621c8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c4362c6-0515-46fc-95a1-6e81a1621c8c")) {                    Plotly.newPlot(                        "3c4362c6-0515-46fc-95a1-6e81a1621c8c",                        [{"alignmentgroup":"True","hovertemplate":"d_yon=yukselen gun<br>ay_y\u0131l=%{x}<br>Degisim%=%{y}<extra></extra>","legendgroup":"yukselen gun","marker":{"color":"green","pattern":{"shape":""}},"name":"yukselen gun","offsetgroup":"yukselen gun","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0%}","x":["2021-01","2021-04","2021-05","2021-07","2021-08","2021-10","2021-11","2021-12","2022-01","2022-03","2022-04","2022-05","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12"],"xaxis":"x","y":[null,0.018312765874303152,0.034319444822652846,0.02590746037429499,0.05830223690912253,0.08669944474712418,0.18774842992214574,0.04231004174693998,0.08770375192901235,0.13305580014036716,0.0917164361578462,0.04925314307143072,0.05798714228864343,0.2513674705103242,0.0009264113602853924,0.25245831724017165,0.23874838987270522,0.10819474925614113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"d_yon=dusen gun<br>ay_y\u0131l=%{x}<br>Degisim%=%{y}<extra></extra>","legendgroup":"dusen gun","marker":{"color":"red","pattern":{"shape":""}},"name":"dusen gun","offsetgroup":"dusen gun","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0%}","x":["2021-02","2021-03","2021-06","2021-09","2022-02","2022-06"],"xaxis":"x","y":[-0.010429931416576891,-0.0805270236684608,-0.029199017378149422,-0.05232015053929053,-0.007400366887057533,-0.08049060425146759],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %% [markdown]
# 3. Ders sonunda hazırladığınız 2021 ve 2022 yıllarına ait BIST30 ve EUR/USD kur değerlerini içeren bileşke tablodan sadece ayın son işgününe ait değerleri içeren bir tabloyu bir de resample yöntemi ile üretiniz.

# %%
Veri_as2=Veri.resample('BM',convention='end').asfreq()
Veri_as2=Veri_as2[Veri_as2['Kapanış (TRY)']>0]
Veri_as2
# Out:
#             Kapanış (TRY)    EUR/TRY   ay_yıl
# 2021-01-29    1572.400024   8.902570  2021-01
# 2021-02-26    1556.000000   8.904670  2021-02
# 2021-03-31    1430.699951   9.748300  2021-03
# 2021-04-30    1456.900024   9.923590  2021-04
# 2021-06-30    1462.900024  10.384030  2021-06
# 2021-07-30    1500.800049  10.050560  2021-07
# 2021-08-31    1588.300049   9.869130  2021-08
# 2021-09-30    1505.199951  10.343790  2021-09
# 2021-11-30    1942.800049  14.347000  2021-11
# 2021-12-31    2025.000000  14.993060  2021-12
# 2022-01-31    2202.600098  15.034780  2022-01
# 2022-02-28    2186.300049  15.688630  2022-02
# 2022-03-31    2477.199951  16.353970  2022-03
# 2022-04-29    2704.399902  15.531140  2022-04
# 2022-05-31    2837.600098  17.646820  2022-05
# 2022-06-30    2609.199951  17.240959  2022-06
# 2022-07-29    2760.500000  18.285971  2022-07
# 2022-08-31    3454.399902  18.194550  2022-08
# 2022-09-30    3457.600098  18.145809  2022-09
# 2022-10-31    4330.500000  18.480520  2022-10
# 2022-11-30    5364.399902  19.230379  2022-11
# 2022-12-30    5944.799805  19.937571  2022-12

# %% [markdown]
# 4. Resample yöntemi ile ürettiğiniz tabloyu grafik olarak inceleyiniz. 2. adımda elde ettiğiniz grafik ile karşılaştırarak yorumlayınız.

# %%
Veri_as2['Degisim'] = Veri_as2['Kapanış (TRY)'].diff(1)
Veri_as2['d_yon']=Veri_as2['Degisim'].map(lambda x:'dusen gun' if x<0 else 'yukselen gun')
Veri_as2['Degisim%']=(Veri_as2['Degisim']/Veri_as2['Kapanış (TRY)'].shift(1))

px.bar(Veri_as,y='Degisim%',
       color='d_yon',
       color_discrete_map={'dusen gun' : 'red','yukselen gun' : 'green'},
       text_auto='.0%'
       )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5a32d6c7-08aa-4347-b0c9-b64d0f5c6854" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a32d6c7-08aa-4347-b0c9-b64d0f5c6854")) {                    Plotly.newPlot(                        "5a32d6c7-08aa-4347-b0c9-b64d0f5c6854",                        [{"alignmentgroup":"True","hovertemplate":"d_yon=yukselen gun<br>ay_y\u0131l=%{x}<br>Degisim%=%{y}<extra></extra>","legendgroup":"yukselen gun","marker":{"color":"green","pattern":{"shape":""}},"name":"yukselen gun","offsetgroup":"yukselen gun","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0%}","x":["2021-01","2021-04","2021-05","2021-07","2021-08","2021-10","2021-11","2021-12","2022-01","2022-03","2022-04","2022-05","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12"],"xaxis":"x","y":[null,0.018312765874303152,0.034319444822652846,0.02590746037429499,0.05830223690912253,0.08669944474712418,0.18774842992214574,0.04231004174693998,0.08770375192901235,0.13305580014036716,0.0917164361578462,0.04925314307143072,0.05798714228864343,0.2513674705103242,0.0009264113602853924,0.25245831724017165,0.23874838987270522,0.10819474925614113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"d_yon=dusen gun<br>ay_y\u0131l=%{x}<br>Degisim%=%{y}<extra></extra>","legendgroup":"dusen gun","marker":{"color":"red","pattern":{"shape":""}},"name":"dusen gun","offsetgroup":"dusen gun","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.0%}","x":["2021-02","2021-03","2021-06","2021-09","2022-02","2022-06"],"xaxis":"x","y":[-0.010429931416576891,-0.0805270236684608,-0.029199017378149422,-0.05232015053929053,-0.007400366887057533,-0.08049060425146759],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %% [markdown]
# *Pivot table ile oluşturduğum verinin grafiği ile resample ile oluşturduğum verinin grafiği arasında fark yok. Resample ile verimi oluşturduğumda NaN satırlar geldi ben de bu sütunları filitreledim. Filitreleme yöntemini tercih etmeseydim convention parametresine end değil de avg derdim. *
